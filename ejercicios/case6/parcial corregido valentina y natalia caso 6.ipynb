# %% [markdown]
# ## Cuarta actividad evaluativa
#
# Profesor Alfonso Cervantes Barragán - 05-10-2020
#
# Universidad Sergio Arboleda - Informatica III

# %% [markdown]
# ### Descripción del contexto.
#
# En esta actividad el estudiante debera realizar un análisis exploratorio de Datos (EDA) del dataset *ventas-de-juegos.csv*, que contiene información sobre videos juegos vendidos que superarion las 100 000 copias.
#
# La siguiente tabla contiene la descripción de las columnas:
#
# |Columna |	Descripción |
# |--------|--------------|
# |Rank|Ranking sobre las ventas totales |
# |Name| Nombre del juego|
# |Platform |	Plataforma mediante la cual fue dado a conocer el juego|
# |year |	año en el que se dio a conocer el juego|
# |genre |genero del juego |
# |Publisher |	editor del juego |
# |NA_sales |Ventas en Norte America (en millones) |
# |EU_sales |Ventas en Europa (en millones) |
# |JP_sales| ventas en Japón (en millones) |
# |Other_sales| ventas en el resto del mundo (en millones)|
# |Global_sales|ventas totales en el mundo|
#
#
# #### Entregable
#
# El estudiante debera entregar un documento con extensión *ipynb* mediante el taller "Cuarta Evaluación " que se encuentra en el curso virtual Informatica III en el plataforma Sergio Virtual
#
#
# #### Plazo
#
# El plazo de entrega sera hasta el sabado, 24 de octubre a las 11:30 p.m. En el aula del curso en la plataforma Sergio Virtual estará disponible un taller en el cual deberan subir el archivo .ipynb (Jupyter notebook) con todo el código requerido.
#
# No esta permitido resolver los ejercicios a mano ni ingresar la respuesta sin que haya un código que lo respalde.
#
# #### Donde puedo trabajar?
#
# Este ejercicio se puede realizar en el entorno virtual creado con base en el repositorio github.com/alfonsocerv/datascience en la carpeta /ejericicio/caso6.
#
# #### Criterios de evaluación
#
# 1. Todo el código requerido debe estar presente. Cada ejercicio debe tener su respectiva respuesta.
# 2. No pueden haber errores que se generen al ejecutar el código.
# 3. El código debe cumplir con las especificaciones de cada ejercicio.

# %% [markdown]
# ### Ejercicio 1
#
# Importa las librerias pandas, numpy y matplotlib
#
# #### Respuesta

# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Lectura de el archivo de datos

# %%
datat = pd.read_csv("ventas-de-juegos.csv")

# %% [markdown]
# ### Mostrar los primeros cinco registros

# %%
datat.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %% [markdown]
# ### Mostrando los últimos 5 registros

# %%
datat.tail()
# Out:
#         Rank                                              Name Platform  \
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year     Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 16593  2002.0  Platform       Kemco      0.01      0.00       0.0
# 16594  2003.0   Shooter  Infogrames      0.01      0.00       0.0
# 16595  2008.0    Racing  Activision      0.00      0.00       0.0
# 16596  2010.0    Puzzle    7G//AMES      0.00      0.01       0.0
# 16597  2003.0  Platform     Wanadoo      0.01      0.00       0.0
#
#        Other_Sales  Global_Sales
# 16593          0.0          0.01
# 16594          0.0          0.01
# ...

# %% [markdown]
# ### Extraiendo los nombres de las columnas

# %%
datat.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %% [markdown]
# ### Extraiendo el maximo valor de la columna NA_Sales.

# %%
datat["NA_Sales"].max()
# Out:
# 41.49

# %% [markdown]
#  El maximo valor que se alcanzaron en las ventas en Norte america es dde 41.49

# %% [markdown]
# ### Extraiendo el maximo valor de la columna EU_Sales.

# %%
datat["EU_Sales"].max()
# Out:
# 29.02

# %% [markdown]
# El maximo valor que se alcanzaron en las ventas en Europa es de 29.02

# %% [markdown]
# ### Extraiendo el maximo valor de la columna Other_Sales.

# %%
datat["Other_Sales"].max()
# Out:
# 10.57

# %% [markdown]
# El maximo valor que se alcanzaron en las ventas en el resto del mundo es de 10.57

# %% [markdown]
# ### Cuales son los nombres de los juegos?

# %%
datat["Name"]
# Out:
# 0                                              Wii Sports
# 1                                       Super Mario Bros.
# 2                                          Mario Kart Wii
# 3                                       Wii Sports Resort
# 4                                Pokemon Red/Pokemon Blue
#                                ...
# 16593                  Woody Woodpecker in Crazy Castle 5
# 16594                       Men in Black II: Alien Escape
# 16595    SCORE International Baja 1000: The Official Game
# 16596                                          Know How 2
# 16597                                    Spirits & Spells
# Name: Name, Length: 16598, dtype: object

# %% [markdown]
# Podemos encontrar que hay 5 juegos en total. 1 Super Mario Bros, 2 Mario Kart Wii, 3 Wii Sports Resort y 4 Pokemon Red/Pokemon Blue

# %% [markdown]
# ### Cual fue el porcentaje de las ventas totales

# %%
datat["Rank"].value_counts()
# Out:
# 2047     1
# 10864    1
# 6822     1
# 677      1
# 2724     1
#         ..
# 1354     1
# 7497     1
# 5448     1
# 11583    1
# 2049     1
# Name: Rank, Length: 16598, dtype: int64

# %% [markdown]
# ### Determinar el número de registros que coinciden con cada uno de los valores.

# %%
datat["NA_Sales"].value_counts()
# Out:
# 0.00     4499
# 0.02      550
# 0.01      541
# 0.03      533
# 0.05      530
#          ...
# 5.99        1
# 14.03       1
# 4.21        1
# 9.03        1
# 9.00        1
# Name: NA_Sales, Length: 409, dtype: int64

# %%
datat["Rank"].value_counts()
# Out:
# 2047     1
# 10864    1
# 6822     1
# 677      1
# 2724     1
#         ..
# 1354     1
# 7497     1
# 5448     1
# 11583    1
# 2049     1
# Name: Rank, Length: 16598, dtype: int64

# %% [markdown]
# ### Accediendo a los resultados del value_counts()

# %%
datat["NA_Sales"].value_counts()[1]/datat["NA_Sales"].count()
# Out:
# 0.0009037233401614652

# %%
datat["Rank"].value_counts()[1]/datat["Rank"].count()

# %% [markdown]
# ### En que año se dio a conocer el juego?

# %%
def year():
    print("El juego Super Mario Bros se dió a conocer en 1985")

# %%
year()
# Out:
# El juego Super Mario Bros se dió a conocer en 1985

# %% [markdown]
# Como todos sabemos, cada juego tuvo su año de creación, por lo que en este caso el de Súper Mario Bross fue en el 1985

# %% [markdown]
# ### De cuanto fueron las ventas en Japón de Super Mario Bros (en millones)?

# %%
def JP_Sales():
    print ("Las ventas en Japón fueron 6.81 millones")

# %%
JP_Sales()
# Out:
# Las ventas en Japón fueron 6.81 millones

# %% [markdown]
# ### Mediante que plataforma se dio a conocer Super Mario Bros?

# %%
def platform():
    print("El juego Super Mario Bros se dió a conocer mediante la plataforma NES")

# %%
platform()
# Out:
# El juego Super Mario Bros se dió a conocer mediante la plataforma NES

# %% [markdown]
# Mario Bross se dio a conocer mediante una de las mejores plataformas la cual contiene los mejores juegos.

# %% [markdown]
# ### Desviación estandard de las ventas en Norte América

# %%
datat["NA_Sales"].std()
# Out:
# 0.8166830292988796

# %% [markdown]
# Se puedo establecer que el valor de referencia para estimar la variación general de las ventas en Norte América fue de 0.81668302

# %% [markdown]
# ### Determine el rango de ventas en Europa

# %%
rango = datat["EU_Sales"].max() - datat["EU_Sales"].min()
print ("El rango de ventas en Europa es:", rango)
# Out:
# El rango de ventas en Europa es: 29.02

# %% [markdown]
# ### Histograma de las ventas globales

# %%
datat["Global_Sales"].hist(bins=15, grid=False, figsize=(15,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Diagrama de dispersión entre las ventas en Norte America y Japón

# %%
datat.plot.scatter(x='NA_Sales', y='JP_Sales', figsize=(9,7))
# Out:
# <AxesSubplot:xlabel='NA_Sales', ylabel='JP_Sales'>

# %% [markdown]
# Según podemos ver en el diagrama de dispersión,  las ventas de japon y y norte America están más centradas entre 0 y 10.

# %% [markdown]
# ### Nombre del juego

# %%
def nombre():
    print("El nombre del juego es Super Mario Bros")

# %%
nombre()
# Out:
# El nombre del juego es Super Mario Bros

# %%
datat.shape
# Out:
# (16598, 11)

# %% [markdown]
# ### Resumen general de los datos

# %%
datat.info
# Out:
# <bound method DataFrame.info of         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# ### Informacion sobre los datos de la columna Year

# %%
datat["Year"].describe()
# Out:
# count    16327.000000
# mean      2006.406443
# std          5.828981
# min       1980.000000
# 25%       2003.000000
# 50%       2007.000000
# 75%       2010.000000
# max       2020.000000
# Name: Year, dtype: float64

# %% [markdown]
# Como podemos ver, la información de la columna year, nos dice cuál fue la desviación estándar, el valor mínimo y los porcentajes (no se) jajaj

# %% [markdown]
# ### Informacion sobre los datos de la columna Genre

# %%
datat["Genre"].describe()
# Out:
# count      16598
# unique        12
# top       Action
# freq        3316
# Name: Genre, dtype: object

# %% [markdown]
# ### Leyendo la base de datos

# %%
datat = pd.read_csv("ventas-de-juegos.csv")
datat.shape
# Out:
# (16598, 11)

# %% [markdown]
# ### Estadisticas con limitado a 3 decimales

# %%
np.round(datat["Other_Sales"].describe(),3)
# Out:
# count    16598.000
# mean         0.048
# std          0.189
# min          0.000
# 25%          0.000
# 50%          0.010
# 75%          0.040
# max         10.570
# Name: Other_Sales, dtype: float64

# %% [markdown]
# ### Distribución de articulos segun el precio

# %%
datat['Other_Sales'].hist(bins=50, figsize=(10,5), edgecolor='white', range=[0,500])
plt.xlabel("Precio", fontsize=15)
plt.ylabel("No. de articulos con ese precio", fontsize=14)
plt.show()

# %% [markdown]
# ### Subtabla con solo las columnas genre and year

# %%
datat=datat[["Genre", "Year"]]
datat.head(12)
# Out:
#            Genre    Year
# 0         Sports  2006.0
# 1       Platform  1985.0
# 2         Racing  2008.0
# 3         Sports  2009.0
# 4   Role-Playing  1996.0
# 5         Puzzle  1989.0
# 6       Platform  2006.0
# 7           Misc  2006.0
# 8       Platform  2009.0
# 9        Shooter  1984.0
# 10    Simulation  2005.0
# 11        Racing  2005.0

# %% [markdown]
# Como se puede ver, esta es una subtabla que  solo contiene los datos de las columnas Genre y Year respectivamente, omitiendo los datos de las demás columnas
