# %% [markdown]
# ## Caso 3-2  TIENDA DE ROPA CASTEL
#
# #### Actividad evaluativa II
#
# Profesor Alfonso Cervantes Barragán - 12-09-2020

# %% [markdown]
# ### Descripción del contexto.
#
# En Blackfriday, la tienda de ropa Castel ofrece a sus clientes la siguiente promoción.
#
# Si el valor de compra de un artículo se encuentra en el rango entre 100 000 y 200 000 pesos, obtiene un 20% de descuento por ese artículo. Si se encuentra entre 200 001 y 500 000 pesos,
# obtiene un 35% de descuento por ese artículo. Si es mayor a 500 001 pesos, obtiene un 50% de descuento por ese artículo.
#
# Las prendas en oferta se encuentran sin IVA, el cuál le sera aplicado al valor total de compra despues de haber aplicado los descuentos. (Considere un 19% de IVA).
#
#
#
# #### Entregable
#
# El estudiante debera entregar un documento con extensión *ipynb* mediante el taller "Segunda Evaluación Informatica III" que se encuentra en el curso virtual Informatica III en el plataforma Sergio Virtual
#
# #### Plazo
#
# El plazo de entrega sera hasta el miercoles, 16 de septiembre a las 11:30 p.m. En el aula del curso en la plataforma Sergio Virtual estará disponible un taller en el cual deberan subir el archivo .ipynb (Jupyter notebook) con todo el código requerido.
#
# No esta permitido resolver los ejercicios a mano ni ingresar la respuesta sin que haya un código que lo respalde.
#
# #### Donde puedo trabajar?
#
# Este ejercicio no se basa en una base de datos y pueden directamente en el directorio del caso 3 en el repositorio del curso alfonsocerv/datascience.
#
# #### Criterios de evaluación
#
# 1. Todo el código requerido debe estar presente. Cada ejercicio debe tener su respectiva respuesta.
# 2. No pueden haber errores que se generen al ejecutar el código.
# 3. El código debe cumplir con las especificaciones de cada ejercicio.

# %% [markdown]
# ### Ejercicio
#
# Cree una lista con los siguientes valores 20000, 90000, 120000, 350000, 495000 y 600000, los cuales representan los precios de 6 prendas ofrecidas en la tienda de ropa Castel.
# Asuma que usted las eligio y va a caja a pagar por ellas bajo las condiciones de la promoción ofrecida.
#
# Escriba un código en python que reciba la lista de valores mencionada anteriormente y calcule el valor total a pagar con el descuento e iva implementados.
#
# El programa debera imprimir la siguiente información:
#
#     Valor total de compra (sin descuento y sin iva).
#     Valor total del descuento (sumatoria de todos los descuentos)
#     Valor total del IVA    (aplicado sobre el valor total con descuento).
#     Valor total a pagar     (con descuento y con iva)

# %%
lista = [20000,90000,120000,350000,495000,600000]
print (lista)
# Out:
# [20000, 90000, 120000, 350000, 495000, 600000]

# %%
#valor sin descuento y sin IVA
valor_total_compra = 0
for numero in lista:
    valor_total_compra = valor_total_compra + numero

print ("Los precios netos de las 6 prendas son de $",  valor_total_compra)
# Out:
# Los precios netos de las 6 prendas son de $ 1675000

# %%
#si el valor de la compra está entre 100000 y 200000, se obtiene 20% de descuento
#si el valor de la compra está entre 100001 y 500000, se obtiene un 35% de descuento
#si el valor de la compra es mayor a 500001, se obtiene un 50% de descuento

if ( valor_total_compra >= 100000 ) & (valor_total_compra < 200000):
    print ("El valor de la compra con descuento es $", valor_total_compra*0.8)
    print ("El descuento realizado es de $", valor_total_compra*0.2)
    
valor_total_compra = int(input("Cual es el valor de la compra?"))
if valor_total_compra < 100000:
    print ("El valor de la compra con descuento es $", valor_total_compra)
    print ("El descuento realizado es $",0)
    
elif (valor_total_compra >= 100000) and (valor_total_compra < 200000):
    print ("El valor de la compra con descuento es $", valor_total_compra*0.8)
    print ("El descuento realizado es de $", valor_total_compra*0.2)
    
elif (valor_total_compra >= 200001) and (valor_total_compra < 500000):
    print ("El valor de la compra con descuento es $", valor_total_compra*0.65)
    print ("El descuento realizado es de $", valor_total_compra*0.35)
    
else:
    print ("El valor de la compra con descuento es $", valor_total_compra*0.5)
    print ("El descuento realizado es de $", valor_total_compra*0.5)
    
    
#ingresar que el valor de la compra fue de $1675000
# Out:
# Cual es el valor de la compra?1675000
# El valor de la compra con descuento es $ 837500.0
# El descuento realizado es de $ 837500.0

# %%
#valor del IVA aplicado sobre el valor de la compra con descuento 
#valor total a pagar con descuento y con IVA

def funcompra(valor, porcentaje):
    print("El valor del IVA para esta compra es de $", valor*porcentaje)   
    print("El valor total a pagar de la compra, con descuento aplicado + IVA es de $", valor*(1+porcentaje))
    
funcompra(837500, 0.19)
# Out:
# El valor del IVA para esta compra es de $ 159125.0
# El valor total a pagar de la compra, con descuento aplicado + IVA es de $ 996625.0
